# %% [markdown]
# <a href="https://colab.research.google.com/github/rahu2004/OPENAI_AITOOLS/blob/main/AI_Business_Automation_Suite_using_Free_LLMsSuite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch gradio

# %% [markdown]
# load model

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="microsoft/DialoGPT-medium")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/863M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/863M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/293 [00:00<?, ?it/s]
# ...

# %% [markdown]
# email generator

# %%
def email_reply(text):
    prompt = f"Reply professionally to this email:\n{text}"
    output = generator(prompt, max_length=150, do_sample=True)
    return output[0]['generated_text']

# %% [markdown]
# cover letter generator

# %%
def cover_letter(resume, job):
    prompt = f"""
Resume: {resume}
Job: {job}

Write a professional cover letter.
"""
    output = generator(prompt, max_length=250)
    return output[0]['generated_text']

# %%
def travel_plan(place, days, interests):
    prompt = f"""
Plan a {days}-day trip to {place}.
Interests: {interests}.
Give itinerary.
"""
    output = generator(prompt, max_length=300)
    return output[0]['generated_text']

# %%
def chatbot(msg):
    output = generator(msg, max_length=120)
    return output[0]['generated_text']

# %%
import gradio as gr

with gr.Blocks() as app:

    gr.Markdown("# 🚀 FREE AI Business Automation Suite")

    with gr.Tab("Email Reply"):
        inp = gr.Textbox()
        out = gr.Textbox()
        gr.Button("Generate").click(email_reply, inp, out)

    with gr.Tab("Cover Letter"):
        r = gr.Textbox()
        j = gr.Textbox()
        out = gr.Textbox()
        gr.Button("Generate").click(cover_letter, [r, j], out)

    with gr.Tab("Travel Planner"):
        p = gr.Textbox()
        d = gr.Number()
        i = gr.Textbox()
        out = gr.Textbox()
        gr.Button("Plan").click(travel_plan, [p, d, i], out)

    with gr.Tab("Chatbot"):
        m = gr.Textbox()
        out = gr.Textbox()
        gr.Button("Ask").click(chatbot, m, out)

app.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://86a7da977e42c34685.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://86a7da977e42c34685.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
